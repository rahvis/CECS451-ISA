# %% [markdown]
# #Pseudocode: Value Iteration

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt


class ValueIteration:
    def __init__(self, reward_function, transition_model, gamma):
        self.num_states = transition_model.shape[0]
        self.num_actions = transition_model.shape[1]
        self.reward_function = np.nan_to_num(reward_function)
        self.transition_model = transition_model
        self.gamma = gamma
        self.values = np.zeros(self.num_states)
        self.policy = None

    def one_iteration(self):
        delta = 0
        for s in range(self.num_states):
            temp = self.values[s]
            v_list = np.zeros(self.num_actions)
            for a in range(self.num_actions):
                p = self.transition_model[s, a]
                v_list[a] = self.reward_function[s] + self.gamma * np.sum(p * self.values)

            self.values[s] = max(v_list)
            delta = max(delta, abs(temp - self.values[s]))
        return delta

    def get_policy(self):
        pi = np.ones(self.num_states) * -1
        for s in range(self.num_states):
            v_list = np.zeros(self.num_actions)
            for a in range(self.num_actions):
                p = self.transition_model[s, a]
                v_list[a] = self.reward_function[s] + self.gamma * np.sum(p * self.values)

            max_index = []
            max_val = np.max(v_list)
            for a in range(self.num_actions):
                if v_list[a] == max_val:
                    max_index.append(a)
            pi[s] = np.random.choice(max_index)
        return pi.astype(int)

    def train(self, tol=1e-3):
        epoch = 0
        delta = self.one_iteration()
        delta_history = [delta]
        while delta > tol:
            epoch += 1
            delta = self.one_iteration()
            delta_history.append(delta)
            if delta < tol:
                break
        self.policy = self.get_policy()

        print(f'# iterations of policy improvement: {len(delta_history)}')
        print(f'delta = {delta_history}')

        fig, ax = plt.subplots(1, 1, figsize=(3, 2), dpi=200)
        ax.plot(np.arange(len(delta_history)) + 1, delta_history, marker='o', markersize=4,
                alpha=0.7, color='#2ca02c', label=r'$\gamma= $' + f'{self.gamma}')
        ax.set_xlabel('Iteration')
        ax.set_ylabel('Delta')
        ax.legend()
        plt.tight_layout()
        plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from time import time


class GridWorld:
    def __init__(self, filename, reward, random_rate, time_limit=1000):
        file = open(filename)
        self.map = np.array(
            [list(map(float, s.strip().split(","))) for s in file.readlines()]
        )
        file.close()
        self.num_rows = self.map.shape[0]
        self.num_cols = self.map.shape[1]
        self.num_states = self.num_rows * self.num_cols
        self.num_actions = 4
        self.reward = reward
        self.random_rate = random_rate
        self.time_limit = time_limit
        self.reward_function = self.get_reward_function()
        self.transition_model = self.get_transition_model()

    def get_state_from_pos(self, pos):
        return pos[0] * self.num_cols + pos[1]

    def get_pos_from_state(self, state):
        return state // self.num_cols, state % self.num_cols

    def get_reward_function(self):
        reward_table = np.zeros(self.num_states)
        for r in range(self.num_rows):
            for c in range(self.num_cols):
                s = self.get_state_from_pos((r, c))
                reward_table[s] = self.reward[self.map[r, c]]
        return reward_table

    def get_transition_model(self):
        transition_model = np.zeros((self.num_states, self.num_actions, self.num_states))
        for r in range(self.num_rows):
            for c in range(self.num_cols):
                s = self.get_state_from_pos((r, c))
                neighbor_s = np.zeros(self.num_actions)
                if self.map[r, c] == 0:
                    for a in range(self.num_actions):
                        new_r, new_c = r, c
                        if a == 0:
                            new_r = max(r - 1, 0)
                        elif a == 1:
                            new_c = min(c + 1, self.num_cols - 1)
                        elif a == 2:
                            new_r = min(r + 1, self.num_rows - 1)
                        elif a == 3:
                            new_c = max(c - 1, 0)
                        if self.map[new_r, new_c] == 3:
                            new_r, new_c = r, c
                        s_prime = self.get_state_from_pos((new_r, new_c))
                        neighbor_s[a] = s_prime
                else:
                    neighbor_s = np.ones(self.num_actions) * s
                for a in range(self.num_actions):
                    transition_model[s, a, int(neighbor_s[a])] += 1 - self.random_rate
                    transition_model[s, a, int(neighbor_s[(a + 1) % self.num_actions])] += self.random_rate / 2.0
                    transition_model[s, a, int(neighbor_s[(a - 1) % self.num_actions])] += self.random_rate / 2.0
        return transition_model

    def generate_random_policy(self):
        return np.random.randint(self.num_actions, size=self.num_states)

    def execute_policy(self, policy, start_pos):
        s = self.get_state_from_pos(start_pos)
        r = self.reward_function[s]
        total_reward = r

        start_time = int(round(time() * 1000))
        overtime = False

        while r != self.reward[1] and r != self.reward[2]:
            s = np.random.choice(self.num_states, p=self.transition_model[s, policy[s]])
            r = self.reward_function[s]
            total_reward += r
            cur_time = int(round(time() * 1000)) - start_time
            if cur_time > self.time_limit:
                overtime = True
                break
        if overtime is True:
            return float('-inf')
        else:
            return total_reward

    def random_start_policy(self, policy, start_pos, n=100, plot=True):
        start_time = int(round(time() * 1000))
        overtime = False
        scores = np.zeros(n)
        i = 0
        while i < n:
            temp = self.execute_policy(policy=policy, start_pos=start_pos)
            print(f'i = {i} Random start result: {temp}')
            if temp > float('-inf'):
                scores[i] = temp
                i += 1
            cur_time = int(round(time() * 1000)) - start_time
            if cur_time > n * self.time_limit:
                overtime = True
                break

        print(f'max = {np.max(scores)}')
        print(f'min = {np.min(scores)}')
        print(f'mean = {np.mean(scores)}')
        print(f'std = {np.std(scores)}')

        if overtime is False and plot is True:
            bins = 100
            fig, ax = plt.subplots(1, 1, figsize=(6, 4), dpi=300)
            ax.set_xlabel('Total rewards in a single game')
            ax.set_ylabel('Frequency')
            ax.hist(scores, bins=bins, color='#1f77b4', edgecolor='black')
            plt.show()

        if overtime is True:
            print('Overtime!')
            return None
        else:
            return np.max(scores), np.min(scores), np.mean(scores)

    def blackbox_move(self, s, a):
        temp = self.transition_model[s, a]
        s_prime = np.random.choice(self.num_states, p=temp)
        r = self.reward_function[s_prime]
        return s_prime, r

    def plot_map(self, fig_size=(8, 6)):
        unit = min(fig_size[1] // self.num_rows, fig_size[0] // self.num_cols)
        unit = max(1, unit)
        fig, ax = plt.subplots(1, 1, figsize=fig_size)
        ax.axis('off')
        for i in range(self.num_cols + 1):
            if i == 0 or i == self.num_cols:
                ax.plot([i * unit, i * unit], [0, self.num_rows * unit],
                        color='black')
            else:
                ax.plot([i * unit, i * unit], [0, self.num_rows * unit],
                        alpha=0.7, color='grey', linestyle='dashed')
        for i in range(self.num_rows + 1):
            if i == 0 or i == self.num_rows:
                ax.plot([0, self.num_cols * unit], [i * unit, i * unit],
                        color='black')
            else:
                ax.plot([0, self.num_cols * unit], [i * unit, i * unit],
                        alpha=0.7, color='grey', linestyle='dashed')

        for i in range(self.num_rows):
            for j in range(self.num_cols):
                y = (self.num_rows - 1 - i) * unit
                x = j * unit
                if self.map[i, j] == 3:
                    rect = patches.Rectangle((x, y), unit, unit, edgecolor='none', facecolor='black',
                                             alpha=0.6)
                    ax.add_patch(rect)
                elif self.map[i, j] == 2:
                    rect = patches.Rectangle((x, y), unit, unit, edgecolor='none', facecolor='red',
                                             alpha=0.6)
                    ax.add_patch(rect)
                elif self.map[i, j] == 1:
                    rect = patches.Rectangle((x, y), unit, unit, edgecolor='none', facecolor='green',
                                             alpha=0.6)
                    ax.add_patch(rect)

        plt.tight_layout()
        plt.show()

    def plot_policy(self, policy, fig_size=(8, 6)):
        unit = min(fig_size[1] // self.num_rows, fig_size[0] // self.num_cols)
        unit = max(1, unit)
        fig, ax = plt.subplots(1, 1, figsize=fig_size)
        ax.axis('off')
        for i in range(self.num_cols + 1):
            if i == 0 or i == self.num_cols:
                ax.plot([i * unit, i * unit], [0, self.num_rows * unit],
                        color='black')
            else:
                ax.plot([i * unit, i * unit], [0, self.num_rows * unit],
                        alpha=0.7, color='grey', linestyle='dashed')
        for i in range(self.num_rows + 1):
            if i == 0 or i == self.num_rows:
                ax.plot([0, self.num_cols * unit], [i * unit, i * unit],
                        color='black')
            else:
                ax.plot([0, self.num_cols * unit], [i * unit, i * unit],
                        alpha=0.7, color='grey', linestyle='dashed')

        for i in range(self.num_rows):
            for j in range(self.num_cols):
                y = (self.num_rows - 1 - i) * unit
                x = j * unit
                if self.map[i, j] == 3:
                    rect = patches.Rectangle((x, y), unit, unit, edgecolor='none', facecolor='black',
                                             alpha=0.6)
                    ax.add_patch(rect)
                elif self.map[i, j] == 2:
                    rect = patches.Rectangle((x, y), unit, unit, edgecolor='none', facecolor='red',
                                             alpha=0.6)
                    ax.add_patch(rect)
                elif self.map[i, j] == 1:
                    rect = patches.Rectangle((x, y), unit, unit, edgecolor='none', facecolor='green',
                                             alpha=0.6)
                    ax.add_patch(rect)
                s = self.get_state_from_pos((i, j))
                if self.map[i, j] == 0:
                    a = policy[s]
                    symbol = ['^', '>', 'v', '<']
                    ax.plot([x + 0.5 * unit], [y + 0.5 * unit], marker=symbol[a],
                            linestyle='none', markersize=max(fig_size)*unit, color='#1f77b4')

        plt.tight_layout()
        plt.show()

    def visualize_value_policy(self, policy, values, fig_size=(8, 6)):
        unit = min(fig_size[1] // self.num_rows, fig_size[0] // self.num_cols)
        unit = max(1, unit)
        fig, ax = plt.subplots(1, 1, figsize=fig_size)
        ax.axis('off')

        for i in range(self.num_cols + 1):
            if i == 0 or i == self.num_cols:
                ax.plot([i * unit, i * unit], [0, self.num_rows * unit],
                        color='black')
            else:
                ax.plot([i * unit, i * unit], [0, self.num_rows * unit],
                        alpha=0.7, color='grey', linestyle='dashed')
        for i in range(self.num_rows + 1):
            if i == 0 or i == self.num_rows:
                ax.plot([0, self.num_cols * unit], [i * unit, i * unit],
                        color='black')
            else:
                ax.plot([0, self.num_cols * unit], [i * unit, i * unit],
                        alpha=0.7, color='grey', linestyle='dashed')

        for i in range(self.num_rows):
            for j in range(self.num_cols):
                y = (self.num_rows - 1 - i) * unit
                x = j * unit
                s = self.get_state_from_pos((i, j))
                if self.map[i, j] == 3:
                    rect = patches.Rectangle((x, y), unit, unit, edgecolor='none', facecolor='black',
                                             alpha=0.6)
                    ax.add_patch(rect)
                elif self.map[i, j] == 2:
                    rect = patches.Rectangle((x, y), unit, unit, edgecolor='none', facecolor='red',
                                             alpha=0.6)
                    ax.add_patch(rect)
                elif self.map[i, j] == 1:
                    rect = patches.Rectangle((x, y), unit, unit, edgecolor='none', facecolor='green',
                                             alpha=0.6)
                    ax.add_patch(rect)
                if self.map[i, j] != 3:
                    ax.text(x + 0.5 * unit, y + 0.5 * unit, f'{values[s]:.4f}',
                            horizontalalignment='center', verticalalignment='center',
                            fontsize=max(fig_size)*unit*0.6)
                if policy is not None:
                    if self.map[i, j] == 0:
                        a = policy[s]
                        symbol = ['^', '>', 'v', '<']
                        ax.plot([x + 0.5 * unit], [y + 0.5 * unit], marker=symbol[a], alpha=0.4,
                                linestyle='none', markersize=max(fig_size)*unit, color='#1f77b4')

        plt.tight_layout()
        plt.show()

# %%
import numpy as np


problem = GridWorld('world00.csv', reward={0: -0.04, 1: 1.0, 2: -1.0, 3: np.NaN}, random_rate=0.2)

solver = ValueIteration(problem.reward_function, problem.transition_model, gamma=0.9)
solver.train()

problem.visualize_value_policy(policy=solver.policy, values=solver.values)
problem.random_start_policy(policy=solver.policy, start_pos=(2, 0), n=1000)
# Out:
# # iterations of policy improvement: 67
# delta = [1.0, 0.8999999999999999, 0.81, 0.7290000000000001, 0.6561000000000003, 0.59049, 0.531441, 0.47829690000000014, 0.43046720999999977, 0.38742048900000015, 0.3486784401000005, 0.3138105960899997, 0.28242953648099967, 0.25418658283289997, 0.2287679245496097, 0.20589113209465015, 0.18530201888518505, 0.16677181699666477, 0.1500946352969983, 0.13508517176729917, 0.12157665459056943, 0.10941898913151249, 0.0984770902183616, 0.08862938119652597, 0.0797664430768723, 0.0717897987691849, 0.06461081889226605, 0.05814973700304016, 0.052334763302736675, 0.047101286972463186, 0.042391158275215446, 0.03815204244769532, 0.034336838202925435, 0.030903154382633247, 0.027812838944369034, 0.025031555049931598, 0.022528399544938793, 0.020275559590444914, 0.018248003631400778, 0.016423203268260522, 0.014780882941435536, 0.01330279464729145, 0.011972515182561594, 0.010775263664305257, 0.009697737297875264, 0.008727963568087915, 0.007855167211278768, 0.0070696504901519575, 0.006362685441136051, 0.005726416897022801, 0.005153775207320521, 0.004638397686587581, 0.004174557917929533, 0.003757102126137113, 0.0033813919135230464, 0.003043252722170209, 0.002738927449954076, 0.002465034704957958, 0.002218531234461807, 0.0019966781110163367, 0.0017970102999136373, 0.001617309269922984, 0.0014555783429308633, 0.0013100205086367112, 0.0011790184577744611, 0.001061116611996482, 0.0009550049507964786]
# <ipython-input-5-eba000ed2f81>:267: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# i = 0 Random start result: 0.6000000000000001
# i = 1 Random start result: 0.76
# i = 2 Random start result: 0.6799999999999999
# i = 3 Random start result: 0.8
# i = 4 Random start result: 0.8
# i = 5 Random start result: 0.8
# i = 6 Random start result: 0.8
# i = 7 Random start result: 0.6799999999999999
# i = 8 Random start result: 0.72
# i = 9 Random start result: 0.6799999999999999
# i = 10 Random start result: 0.8
# i = 11 Random start result: 0.72
# i = 12 Random start result: 0.6799999999999999
# i = 13 Random start result: 0.72
# i = 14 Random start result: 0.76
# i = 15 Random start result: 0.6799999999999999
# i = 16 Random start result: 0.72
# i = 17 Random start result: 0.76
# i = 18 Random start result: 0.56
# i = 19 Random start result: 0.76
# i = 20 Random start result: 0.6799999999999999
# i = 21 Random start result: 0.76
# i = 22 Random start result: 0.76
# i = 23 Random start result: 0.8
# i = 24 Random start result: 0.8
# i = 25 Random start result: 0.8
# i = 26 Random start result: 0.76
# i = 27 Random start result: 0.8
# i = 28 Random start result: 0.8
# i = 29 Random start result: 0.76
# i = 30 Random start result: 0.56
# i = 31 Random start result: 0.72
# i = 32 Random start result: 0.8
# i = 33 Random start result: 0.8
# i = 34 Random start result: 0.8
# i = 35 Random start result: 0.72
# i = 36 Random start result: 0.8
# i = 37 Random start result: 0.76
# i = 38 Random start result: 0.6799999999999999
# i = 39 Random start result: 0.76
# i = 40 Random start result: 0.8
# i = 41 Random start result: 0.8
# i = 42 Random start result: 0.72
# i = 43 Random start result: 0.56
# i = 44 Random start result: 0.56
# i = 45 Random start result: 0.8
# i = 46 Random start result: 0.8
# i = 47 Random start result: 0.8
# i = 48 Random start result: 0.8
# i = 49 Random start result: 0.72
# i = 50 Random start result: 0.56
# i = 51 Random start result: 0.8
# i = 52 Random start result: 0.6000000000000001
# i = 53 Random start result: 0.72
# i = 54 Random start result: 0.72
# i = 55 Random start result: 0.76
# i = 56 Random start result: 0.76
# i = 57 Random start result: 0.8
# i = 58 Random start result: -1.4
# i = 59 Random start result: 0.76
# i = 60 Random start result: 0.6000000000000001
# i = 61 Random start result: 0.72
# i = 62 Random start result: 0.8
# i = 63 Random start result: 0.8
# i = 64 Random start result: 0.8
# i = 65 Random start result: 0.64
# i = 66 Random start result: 0.72
# i = 67 Random start result: 0.8
# i = 68 Random start result: 0.8
# i = 69 Random start result: 0.8
# i = 70 Random start result: 0.72
# i = 71 Random start result: 0.72
# i = 72 Random start result: 0.72
# i = 73 Random start result: 0.72
# i = 74 Random start result: 0.72
# i = 75 Random start result: 0.64
# i = 76 Random start result: 0.72
# i = 77 Random start result: 0.76
# i = 78 Random start result: 0.8
# i = 79 Random start result: 0.8
# i = 80 Random start result: 0.8
# i = 81 Random start result: 0.6799999999999999
# i = 82 Random start result: 0.6799999999999999
# i = 83 Random start result: 0.8
# i = 84 Random start result: 0.64
# i = 85 Random start result: 0.76
# i = 86 Random start result: 0.8
# i = 87 Random start result: 0.8
# i = 88 Random start result: 0.72
# i = 89 Random start result: 0.72
# i = 90 Random start result: 0.6799999999999999
# i = 91 Random start result: 0.76
# i = 92 Random start result: 0.72
# i = 93 Random start result: 0.72
# i = 94 Random start result: 0.72
# i = 95 Random start result: -1.28
# i = 96 Random start result: 0.8
# i = 97 Random start result: 0.8
# i = 98 Random start result: 0.76
# i = 99 Random start result: 0.64
# i = 100 Random start result: 0.8
# i = 101 Random start result: 0.6000000000000001
# i = 102 Random start result: 0.76
# i = 103 Random start result: 0.64
# i = 104 Random start result: 0.76
# i = 105 Random start result: 0.8
# i = 106 Random start result: 0.56
# i = 107 Random start result: 0.6799999999999999
# i = 108 Random start result: 0.8
# i = 109 Random start result: 0.6000000000000001
# i = 110 Random start result: 0.6799999999999999
# i = 111 Random start result: 0.76
# i = 112 Random start result: 0.8
# i = 113 Random start result: 0.76
# i = 114 Random start result: 0.64
# i = 115 Random start result: 0.72
# i = 116 Random start result: 0.76
# i = 117 Random start result: 0.6000000000000001
# i = 118 Random start result: 0.76
# i = 119 Random start result: 0.8
# i = 120 Random start result: 0.8
# i = 121 Random start result: 0.8
# i = 122 Random start result: 0.6000000000000001
# i = 123 Random start result: 0.72
# i = 124 Random start result: 0.8
# i = 125 Random start result: 0.8
# i = 126 Random start result: 0.8
# i = 127 Random start result: 0.72
# i = 128 Random start result: 0.56
# i = 129 Random start result: 0.8
# i = 130 Random start result: 0.8
# i = 131 Random start result: 0.6799999999999999
# i = 132 Random start result: 0.8
# i = 133 Random start result: 0.6000000000000001
# i = 134 Random start result: 0.56
# i = 135 Random start result: 0.76
# i = 136 Random start result: 0.8
# i = 137 Random start result: 0.64
# i = 138 Random start result: 0.56
# i = 139 Random start result: 0.76
# i = 140 Random start result: 0.72
# i = 141 Random start result: 0.8
# i = 142 Random start result: 0.8
# i = 143 Random start result: 0.76
# i = 144 Random start result: 0.72
# i = 145 Random start result: 0.6799999999999999
# i = 146 Random start result: 0.8
# i = 147 Random start result: 0.8
# i = 148 Random start result: 0.6799999999999999
# i = 149 Random start result: 0.8
# i = 150 Random start result: 0.6799999999999999
# i = 151 Random start result: 0.8
# i = 152 Random start result: 0.8
# i = 153 Random start result: 0.6000000000000001
# i = 154 Random start result: 0.76
# i = 155 Random start result: 0.72
# i = 156 Random start result: 0.76
# i = 157 Random start result: 0.8
# i = 158 Random start result: 0.76
# i = 159 Random start result: 0.6799999999999999
# i = 160 Random start result: 0.8
# i = 161 Random start result: 0.72
# i = 162 Random start result: 0.72
# i = 163 Random start result: 0.76
# i = 164 Random start result: 0.8
# i = 165 Random start result: 0.76
# i = 166 Random start result: 0.6000000000000001
# i = 167 Random start result: 0.76
# i = 168 Random start result: 0.8
# i = 169 Random start result: 0.72
# i = 170 Random start result: 0.6799999999999999
# i = 171 Random start result: 0.6000000000000001
# i = 172 Random start result: 0.8
# i = 173 Random start result: 0.76
# i = 174 Random start result: 0.6000000000000001
# i = 175 Random start result: 0.6799999999999999
# i = 176 Random start result: 0.72
# i = 177 Random start result: 0.72
# i = 178 Random start result: 0.76
# i = 179 Random start result: 0.76
# i = 180 Random start result: 0.76
# i = 181 Random start result: 0.8
# i = 182 Random start result: 0.64
# i = 183 Random start result: 0.8
# i = 184 Random start result: 0.8
# i = 185 Random start result: 0.6000000000000001
# i = 186 Random start result: 0.8
# i = 187 Random start result: 0.76
# i = 188 Random start result: 0.8
# i = 189 Random start result: 0.76
# i = 190 Random start result: 0.8
# i = 191 Random start result: 0.72
# i = 192 Random start result: 0.6799999999999999
# i = 193 Random start result: 0.72
# i = 194 Random start result: 0.8
# i = 195 Random start result: -1.24
# i = 196 Random start result: 0.72
# i = 197 Random start result: 0.6799999999999999
# i = 198 Random start result: 0.64
# i = 199 Random start result: 0.76
# i = 200 Random start result: 0.8
# i = 201 Random start result: 0.56
# i = 202 Random start result: 0.8
# i = 203 Random start result: 0.72
# i = 204 Random start result: 0.72
# i = 205 Random start result: 0.72
# i = 206 Random start result: 0.64
# i = 207 Random start result: 0.8
# i = 208 Random start result: 0.76
# i = 209 Random start result: 0.64
# i = 210 Random start result: 0.52
# i = 211 Random start result: 0.8
# i = 212 Random start result: 0.76
# i = 213 Random start result: 0.6799999999999999
# i = 214 Random start result: 0.6799999999999999
# i = 215 Random start result: 0.76
# i = 216 Random start result: 0.76
# i = 217 Random start result: 0.8
# i = 218 Random start result: 0.6799999999999999
# i = 219 Random start result: 0.76
# i = 220 Random start result: 0.64
# i = 221 Random start result: 0.6000000000000001
# i = 222 Random start result: 0.8
# i = 223 Random start result: 0.8
# i = 224 Random start result: 0.64
# i = 225 Random start result: 0.64
# i = 226 Random start result: 0.76
# i = 227 Random start result: 0.8
# i = 228 Random start result: 0.72
# i = 229 Random start result: 0.76
# i = 230 Random start result: 0.72
# i = 231 Random start result: 0.6000000000000001
# i = 232 Random start result: 0.76
# i = 233 Random start result: 0.76
# i = 234 Random start result: 0.8
# i = 235 Random start result: 0.72
# i = 236 Random start result: 0.72
# i = 237 Random start result: 0.8
# i = 238 Random start result: 0.6799999999999999
# i = 239 Random start result: -1.28
# i = 240 Random start result: 0.8
# i = 241 Random start result: 0.72
# i = 242 Random start result: 0.8
# i = 243 Random start result: 0.76
# i = 244 Random start result: 0.76
# i = 245 Random start result: 0.6000000000000001
# i = 246 Random start result: 0.76
# i = 247 Random start result: 0.64
# i = 248 Random start result: 0.6799999999999999
# i = 249 Random start result: 0.6799999999999999
# i = 250 Random start result: 0.8
# i = 251 Random start result: 0.72
# i = 252 Random start result: 0.8
# i = 253 Random start result: 0.72
# i = 254 Random start result: 0.6000000000000001
# i = 255 Random start result: 0.6799999999999999
# i = 256 Random start result: 0.72
# i = 257 Random start result: 0.76
# i = 258 Random start result: 0.8
# i = 259 Random start result: 0.8
# i = 260 Random start result: 0.8
# i = 261 Random start result: 0.76
# i = 262 Random start result: 0.72
# i = 263 Random start result: 0.76
# i = 264 Random start result: 0.76
# i = 265 Random start result: 0.8
# i = 266 Random start result: 0.8
# i = 267 Random start result: 0.8
# i = 268 Random start result: 0.72
# i = 269 Random start result: 0.44000000000000006
# i = 270 Random start result: 0.6799999999999999
# i = 271 Random start result: 0.72
# i = 272 Random start result: 0.8
# i = 273 Random start result: 0.76
# i = 274 Random start result: 0.76
# i = 275 Random start result: 0.6799999999999999
# i = 276 Random start result: 0.8
# i = 277 Random start result: 0.76
# i = 278 Random start result: 0.76
# i = 279 Random start result: 0.72
# i = 280 Random start result: 0.76
# i = 281 Random start result: -1.28
# i = 282 Random start result: 0.8
# i = 283 Random start result: 0.6000000000000001
# i = 284 Random start result: 0.76
# i = 285 Random start result: 0.8
# i = 286 Random start result: 0.6000000000000001
# i = 287 Random start result: 0.8
# i = 288 Random start result: 0.6799999999999999
# i = 289 Random start result: 0.8
# i = 290 Random start result: 0.8
# i = 291 Random start result: 0.76
# i = 292 Random start result: 0.76
# i = 293 Random start result: 0.6000000000000001
# i = 294 Random start result: 0.8
# i = 295 Random start result: 0.76
# i = 296 Random start result: 0.6000000000000001
# i = 297 Random start result: 0.72
# i = 298 Random start result: 0.6000000000000001
# i = 299 Random start result: 0.76
# i = 300 Random start result: 0.76
# i = 301 Random start result: 0.64
# i = 302 Random start result: 0.8
# i = 303 Random start result: 0.72
# i = 304 Random start result: 0.76
# i = 305 Random start result: 0.76
# i = 306 Random start result: 0.72
# i = 307 Random start result: 0.8
# i = 308 Random start result: 0.6799999999999999
# i = 309 Random start result: -1.28
# i = 310 Random start result: 0.76
# i = 311 Random start result: 0.76
# i = 312 Random start result: 0.8
# i = 313 Random start result: 0.72
# i = 314 Random start result: 0.6000000000000001
# i = 315 Random start result: 0.72
# i = 316 Random start result: 0.76
# i = 317 Random start result: 0.52
# i = 318 Random start result: 0.76
# i = 319 Random start result: 0.76
# i = 320 Random start result: 0.4800000000000001
# i = 321 Random start result: 0.8
# i = 322 Random start result: 0.6000000000000001
# i = 323 Random start result: 0.76
# i = 324 Random start result: 0.6000000000000001
# i = 325 Random start result: 0.8
# i = 326 Random start result: 0.8
# i = 327 Random start result: 0.6799999999999999
# i = 328 Random start result: 0.72
# i = 329 Random start result: 0.64
# i = 330 Random start result: 0.76
# i = 331 Random start result: 0.76
# i = 332 Random start result: 0.8
# i = 333 Random start result: 0.76
# i = 334 Random start result: 0.72
# i = 335 Random start result: 0.8
# i = 336 Random start result: 0.72
# i = 337 Random start result: 0.8
# i = 338 Random start result: 0.8
# i = 339 Random start result: 0.76
# i = 340 Random start result: 0.72
# i = 341 Random start result: 0.8
# i = 342 Random start result: 0.8
# i = 343 Random start result: 0.76
# i = 344 Random start result: 0.76
# i = 345 Random start result: 0.8
# i = 346 Random start result: 0.8
# i = 347 Random start result: 0.8
# i = 348 Random start result: 0.8
# i = 349 Random start result: 0.8
# i = 350 Random start result: 0.72
# i = 351 Random start result: 0.6799999999999999
# i = 352 Random start result: 0.72
# i = 353 Random start result: 0.8
# i = 354 Random start result: 0.76
# i = 355 Random start result: 0.76
# i = 356 Random start result: 0.72
# i = 357 Random start result: 0.64
# i = 358 Random start result: 0.72
# i = 359 Random start result: 0.76
# i = 360 Random start result: 0.72
# i = 361 Random start result: 0.8
# i = 362 Random start result: 0.6799999999999999
# i = 363 Random start result: 0.8
# i = 364 Random start result: 0.76
# i = 365 Random start result: 0.8
# i = 366 Random start result: 0.8
# i = 367 Random start result: 0.72
# i = 368 Random start result: 0.8
# i = 369 Random start result: 0.8
# i = 370 Random start result: 0.8
# i = 371 Random start result: 0.72
# i = 372 Random start result: 0.8
# i = 373 Random start result: 0.72
# i = 374 Random start result: 0.64
# i = 375 Random start result: 0.72
# i = 376 Random start result: 0.72
# i = 377 Random start result: 0.6000000000000001
# i = 378 Random start result: 0.6799999999999999
# i = 379 Random start result: 0.8
# i = 380 Random start result: 0.64
# i = 381 Random start result: 0.8
# i = 382 Random start result: 0.72
# i = 383 Random start result: 0.76
# i = 384 Random start result: 0.8
# i = 385 Random start result: 0.64
# i = 386 Random start result: 0.76
# i = 387 Random start result: 0.56
# i = 388 Random start result: 0.6000000000000001
# i = 389 Random start result: 0.72
# i = 390 Random start result: 0.8
# i = 391 Random start result: 0.64
# i = 392 Random start result: 0.64
# i = 393 Random start result: 0.76
# i = 394 Random start result: 0.72
# i = 395 Random start result: 0.6799999999999999
# i = 396 Random start result: 0.8
# i = 397 Random start result: 0.6799999999999999
# i = 398 Random start result: 0.76
# i = 399 Random start result: 0.72
# i = 400 Random start result: 0.72
# i = 401 Random start result: 0.72
# i = 402 Random start result: 0.8
# i = 403 Random start result: 0.76
# i = 404 Random start result: 0.72
# i = 405 Random start result: 0.8
# i = 406 Random start result: 0.76
# i = 407 Random start result: 0.76
# i = 408 Random start result: 0.6799999999999999
# i = 409 Random start result: 0.76
# i = 410 Random start result: 0.8
# i = 411 Random start result: 0.76
# i = 412 Random start result: 0.8
# i = 413 Random start result: 0.76
# i = 414 Random start result: 0.76
# i = 415 Random start result: 0.8
# i = 416 Random start result: 0.76
# i = 417 Random start result: 0.6000000000000001
# i = 418 Random start result: 0.8
# i = 419 Random start result: 0.8
# i = 420 Random start result: 0.64
# i = 421 Random start result: 0.6799999999999999
# i = 422 Random start result: 0.6000000000000001
# i = 423 Random start result: 0.6799999999999999
# i = 424 Random start result: 0.72
# i = 425 Random start result: 0.8
# i = 426 Random start result: 0.72
# i = 427 Random start result: 0.72
# i = 428 Random start result: 0.8
# i = 429 Random start result: 0.76
# i = 430 Random start result: 0.76
# i = 431 Random start result: 0.6799999999999999
# i = 432 Random start result: 0.8
# i = 433 Random start result: 0.72
# i = 434 Random start result: 0.6799999999999999
# i = 435 Random start result: 0.72
# i = 436 Random start result: 0.76
# i = 437 Random start result: 0.76
# i = 438 Random start result: 0.6799999999999999
# i = 439 Random start result: 0.72
# i = 440 Random start result: 0.76
# i = 441 Random start result: 0.76
# i = 442 Random start result: 0.64
# i = 443 Random start result: 0.76
# i = 444 Random start result: 0.72
# i = 445 Random start result: 0.8
# i = 446 Random start result: 0.8
# i = 447 Random start result: 0.8
# i = 448 Random start result: 0.8
# i = 449 Random start result: 0.8
# i = 450 Random start result: 0.64
# i = 451 Random start result: 0.6000000000000001
# i = 452 Random start result: 0.76
# i = 453 Random start result: 0.76
# i = 454 Random start result: 0.76
# i = 455 Random start result: 0.8
# i = 456 Random start result: -1.28
# i = 457 Random start result: 0.8
# i = 458 Random start result: 0.76
# i = 459 Random start result: 0.72
# i = 460 Random start result: 0.6799999999999999
# i = 461 Random start result: 0.76
# i = 462 Random start result: 0.8
# i = 463 Random start result: -1.3599999999999999
# i = 464 Random start result: 0.72
# i = 465 Random start result: 0.8
# i = 466 Random start result: 0.64
# i = 467 Random start result: 0.72
# i = 468 Random start result: 0.6799999999999999
# i = 469 Random start result: 0.6799999999999999
# i = 470 Random start result: 0.44000000000000006
# i = 471 Random start result: 0.76
# i = 472 Random start result: 0.76
# i = 473 Random start result: 0.64
# i = 474 Random start result: 0.6799999999999999
# i = 475 Random start result: 0.6799999999999999
# i = 476 Random start result: 0.8
# i = 477 Random start result: 0.72
# i = 478 Random start result: 0.56
# i = 479 Random start result: 0.6799999999999999
# i = 480 Random start result: 0.72
# i = 481 Random start result: 0.6799999999999999
# i = 482 Random start result: 0.76
# i = 483 Random start result: 0.8
# i = 484 Random start result: 0.8
# i = 485 Random start result: 0.8
# i = 486 Random start result: 0.64
# i = 487 Random start result: 0.6000000000000001
# i = 488 Random start result: 0.8
# i = 489 Random start result: 0.8
# i = 490 Random start result: 0.6799999999999999
# i = 491 Random start result: 0.76
# i = 492 Random start result: -1.24
# i = 493 Random start result: 0.8
# i = 494 Random start result: 0.64
# i = 495 Random start result: 0.64
# i = 496 Random start result: 0.8
# i = 497 Random start result: 0.8
# i = 498 Random start result: 0.6799999999999999
# i = 499 Random start result: 0.8
# i = 500 Random start result: 0.76
# i = 501 Random start result: 0.72
# i = 502 Random start result: 0.6000000000000001
# i = 503 Random start result: 0.72
# i = 504 Random start result: 0.72
# i = 505 Random start result: 0.8
# i = 506 Random start result: 0.8
# i = 507 Random start result: 0.8
# i = 508 Random start result: 0.8
# i = 509 Random start result: 0.76
# i = 510 Random start result: 0.76
# i = 511 Random start result: 0.72
# i = 512 Random start result: 0.76
# i = 513 Random start result: 0.8
# i = 514 Random start result: 0.76
# i = 515 Random start result: 0.6000000000000001
# i = 516 Random start result: 0.8
# i = 517 Random start result: 0.6799999999999999
# i = 518 Random start result: 0.76
# i = 519 Random start result: 0.72
# i = 520 Random start result: 0.6000000000000001
# i = 521 Random start result: 0.6000000000000001
# i = 522 Random start result: 0.76
# i = 523 Random start result: 0.8
# i = 524 Random start result: 0.8
# i = 525 Random start result: 0.76
# i = 526 Random start result: 0.8
# i = 527 Random start result: 0.8
# i = 528 Random start result: 0.76
# i = 529 Random start result: 0.64
# i = 530 Random start result: 0.6799999999999999
# i = 531 Random start result: 0.8
# i = 532 Random start result: 0.8
# i = 533 Random start result: 0.72
# i = 534 Random start result: 0.64
# i = 535 Random start result: 0.8
# i = 536 Random start result: 0.72
# i = 537 Random start result: 0.8
# i = 538 Random start result: 0.6000000000000001
# i = 539 Random start result: 0.8
# i = 540 Random start result: 0.6799999999999999
# i = 541 Random start result: 0.8
# i = 542 Random start result: 0.72
# i = 543 Random start result: 0.8
# i = 544 Random start result: 0.8
# i = 545 Random start result: 0.76
# i = 546 Random start result: 0.72
# i = 547 Random start result: 0.76
# i = 548 Random start result: 0.8
# i = 549 Random start result: 0.64
# i = 550 Random start result: 0.8
# i = 551 Random start result: 0.8
# i = 552 Random start result: 0.72
# i = 553 Random start result: 0.8
# i = 554 Random start result: 0.76
# i = 555 Random start result: 0.8
# i = 556 Random start result: 0.76
# i = 557 Random start result: 0.6799999999999999
# i = 558 Random start result: 0.76
# i = 559 Random start result: 0.72
# i = 560 Random start result: 0.76
# i = 561 Random start result: 0.8
# i = 562 Random start result: 0.8
# i = 563 Random start result: 0.8
# i = 564 Random start result: 0.8
# i = 565 Random start result: 0.8
# i = 566 Random start result: 0.8
# i = 567 Random start result: 0.6799999999999999
# i = 568 Random start result: 0.8
# i = 569 Random start result: 0.76
# i = 570 Random start result: 0.52
# i = 571 Random start result: 0.8
# i = 572 Random start result: 0.76
# i = 573 Random start result: 0.76
# i = 574 Random start result: 0.8
# i = 575 Random start result: 0.76
# i = 576 Random start result: 0.8
# i = 577 Random start result: 0.6000000000000001
# i = 578 Random start result: 0.6799999999999999
# i = 579 Random start result: 0.72
# i = 580 Random start result: 0.64
# i = 581 Random start result: 0.8
# i = 582 Random start result: 0.76
# i = 583 Random start result: 0.8
# i = 584 Random start result: 0.8
# i = 585 Random start result: 0.76
# i = 586 Random start result: 0.76
# i = 587 Random start result: 0.8
# i = 588 Random start result: 0.64
# i = 589 Random start result: 0.8
# i = 590 Random start result: 0.8
# i = 591 Random start result: 0.8
# i = 592 Random start result: 0.72
# i = 593 Random start result: 0.8
# i = 594 Random start result: 0.8
# i = 595 Random start result: 0.8
# i = 596 Random start result: 0.8
# i = 597 Random start result: 0.8
# i = 598 Random start result: 0.76
# i = 599 Random start result: 0.76
# i = 600 Random start result: 0.6000000000000001
# i = 601 Random start result: 0.8
# i = 602 Random start result: 0.72
# i = 603 Random start result: 0.8
# i = 604 Random start result: 0.76
# i = 605 Random start result: 0.8
# i = 606 Random start result: 0.6799999999999999
# i = 607 Random start result: 0.64
# i = 608 Random start result: 0.72
# i = 609 Random start result: 0.8
# i = 610 Random start result: 0.64
# i = 611 Random start result: 0.76
# i = 612 Random start result: 0.6799999999999999
# i = 613 Random start result: 0.72
# i = 614 Random start result: 0.64
# i = 615 Random start result: 0.6799999999999999
# i = 616 Random start result: 0.76
# i = 617 Random start result: 0.72
# i = 618 Random start result: 0.76
# i = 619 Random start result: 0.6799999999999999
# i = 620 Random start result: 0.72
# i = 621 Random start result: 0.6000000000000001
# i = 622 Random start result: 0.8
# i = 623 Random start result: 0.76
# i = 624 Random start result: 0.76
# i = 625 Random start result: 0.8
# i = 626 Random start result: 0.8
# i = 627 Random start result: 0.56
# i = 628 Random start result: 0.8
# i = 629 Random start result: 0.8
# i = 630 Random start result: 0.6000000000000001
# i = 631 Random start result: 0.76
# i = 632 Random start result: 0.6799999999999999
# i = 633 Random start result: 0.76
# i = 634 Random start result: 0.64
# i = 635 Random start result: 0.76
# i = 636 Random start result: 0.72
# i = 637 Random start result: 0.8
# i = 638 Random start result: 0.76
# i = 639 Random start result: 0.76
# i = 640 Random start result: 0.64
# i = 641 Random start result: 0.8
# i = 642 Random start result: 0.6799999999999999
# i = 643 Random start result: 0.6799999999999999
# i = 644 Random start result: 0.72
# i = 645 Random start result: 0.76
# i = 646 Random start result: 0.8
# i = 647 Random start result: 0.8
# i = 648 Random start result: 0.8
# i = 649 Random start result: 0.8
# i = 650 Random start result: 0.72
# i = 651 Random start result: 0.76
# i = 652 Random start result: 0.8
# i = 653 Random start result: 0.76
# i = 654 Random start result: 0.6000000000000001
# i = 655 Random start result: 0.8
# i = 656 Random start result: 0.8
# i = 657 Random start result: 0.76
# i = 658 Random start result: 0.76
# i = 659 Random start result: 0.76
# i = 660 Random start result: 0.72
# i = 661 Random start result: 0.8
# i = 662 Random start result: 0.76
# i = 663 Random start result: 0.72
# i = 664 Random start result: 0.72
# i = 665 Random start result: 0.8
# i = 666 Random start result: 0.52
# i = 667 Random start result: 0.6000000000000001
# i = 668 Random start result: -1.3599999999999999
# i = 669 Random start result: 0.72
# i = 670 Random start result: 0.76
# i = 671 Random start result: 0.76
# i = 672 Random start result: 0.8
# i = 673 Random start result: 0.8
# i = 674 Random start result: 0.76
# i = 675 Random start result: 0.76
# i = 676 Random start result: 0.76
# i = 677 Random start result: 0.76
# i = 678 Random start result: 0.72
# i = 679 Random start result: 0.64
# i = 680 Random start result: 0.8
# i = 681 Random start result: 0.6000000000000001
# i = 682 Random start result: 0.72
# i = 683 Random start result: 0.76
# i = 684 Random start result: 0.8
# i = 685 Random start result: 0.8
# i = 686 Random start result: 0.64
# i = 687 Random start result: 0.64
# i = 688 Random start result: 0.6799999999999999
# i = 689 Random start result: 0.64
# i = 690 Random start result: 0.76
# i = 691 Random start result: 0.72
# i = 692 Random start result: 0.6799999999999999
# i = 693 Random start result: 0.8
# i = 694 Random start result: 0.56
# i = 695 Random start result: 0.8
# i = 696 Random start result: 0.76
# i = 697 Random start result: 0.76
# i = 698 Random start result: 0.8
# i = 699 Random start result: 0.6799999999999999
# i = 700 Random start result: 0.6000000000000001
# i = 701 Random start result: 0.8
# i = 702 Random start result: 0.8
# i = 703 Random start result: 0.8
# i = 704 Random start result: 0.56
# i = 705 Random start result: 0.56
# i = 706 Random start result: 0.72
# i = 707 Random start result: 0.76
# i = 708 Random start result: 0.76
# i = 709 Random start result: 0.76
# i = 710 Random start result: 0.6799999999999999
# i = 711 Random start result: 0.8
# i = 712 Random start result: 0.8
# i = 713 Random start result: 0.8
# i = 714 Random start result: 0.8
# i = 715 Random start result: 0.8
# i = 716 Random start result: 0.64
# i = 717 Random start result: 0.76
# i = 718 Random start result: 0.8
# i = 719 Random start result: 0.6799999999999999
# i = 720 Random start result: 0.8
# i = 721 Random start result: 0.76
# i = 722 Random start result: 0.72
# i = 723 Random start result: 0.8
# i = 724 Random start result: 0.8
# i = 725 Random start result: 0.72
# i = 726 Random start result: 0.8
# i = 727 Random start result: 0.8
# i = 728 Random start result: 0.8
# i = 729 Random start result: 0.76
# i = 730 Random start result: 0.6799999999999999
# i = 731 Random start result: 0.8
# i = 732 Random start result: 0.8
# i = 733 Random start result: 0.8
# i = 734 Random start result: 0.76
# i = 735 Random start result: 0.72
# i = 736 Random start result: 0.76
# i = 737 Random start result: 0.8
# i = 738 Random start result: 0.76
# i = 739 Random start result: 0.8
# i = 740 Random start result: 0.8
# i = 741 Random start result: 0.8
# i = 742 Random start result: 0.8
# i = 743 Random start result: 0.56
# i = 744 Random start result: 0.6799999999999999
# i = 745 Random start result: 0.72
# i = 746 Random start result: 0.8
# i = 747 Random start result: 0.8
# i = 748 Random start result: 0.8
# i = 749 Random start result: 0.76
# i = 750 Random start result: 0.72
# i = 751 Random start result: 0.8
# i = 752 Random start result: 0.8
# i = 753 Random start result: 0.6000000000000001
# i = 754 Random start result: 0.72
# i = 755 Random start result: 0.6799999999999999
# i = 756 Random start result: 0.56
# i = 757 Random start result: 0.76
# i = 758 Random start result: 0.6799999999999999
# i = 759 Random start result: 0.72
# i = 760 Random start result: 0.8
# i = 761 Random start result: 0.72
# i = 762 Random start result: 0.6799999999999999
# i = 763 Random start result: 0.76
# i = 764 Random start result: 0.76
# i = 765 Random start result: 0.8
# i = 766 Random start result: 0.6799999999999999
# i = 767 Random start result: 0.76
# i = 768 Random start result: 0.6799999999999999
# i = 769 Random start result: 0.8
# i = 770 Random start result: 0.64
# i = 771 Random start result: 0.8
# i = 772 Random start result: 0.76
# i = 773 Random start result: 0.72
# i = 774 Random start result: 0.76
# i = 775 Random start result: 0.6799999999999999
# i = 776 Random start result: 0.64
# i = 777 Random start result: 0.76
# i = 778 Random start result: 0.8
# i = 779 Random start result: 0.72
# i = 780 Random start result: 0.76
# i = 781 Random start result: 0.72
# i = 782 Random start result: 0.72
# i = 783 Random start result: 0.8
# i = 784 Random start result: 0.6799999999999999
# i = 785 Random start result: 0.72
# i = 786 Random start result: 0.6000000000000001
# i = 787 Random start result: 0.76
# i = 788 Random start result: 0.76
# i = 789 Random start result: 0.6799999999999999
# i = 790 Random start result: 0.8
# i = 791 Random start result: 0.6799999999999999
# i = 792 Random start result: 0.72
# i = 793 Random start result: 0.8
# i = 794 Random start result: 0.6000000000000001
# i = 795 Random start result: 0.6799999999999999
# i = 796 Random start result: 0.76
# i = 797 Random start result: 0.76
# i = 798 Random start result: 0.76
# i = 799 Random start result: 0.8
# i = 800 Random start result: 0.8
# i = 801 Random start result: 0.76
# i = 802 Random start result: 0.76
# i = 803 Random start result: 0.72
# i = 804 Random start result: 0.76
# i = 805 Random start result: 0.76
# i = 806 Random start result: 0.8
# i = 807 Random start result: 0.76
# i = 808 Random start result: 0.6799999999999999
# i = 809 Random start result: 0.76
# i = 810 Random start result: 0.6799999999999999
# i = 811 Random start result: 0.6799999999999999
# i = 812 Random start result: 0.72
# i = 813 Random start result: 0.76
# i = 814 Random start result: 0.8
# i = 815 Random start result: 0.76
# i = 816 Random start result: 0.8
# i = 817 Random start result: 0.72
# i = 818 Random start result: 0.6799999999999999
# i = 819 Random start result: 0.6799999999999999
# i = 820 Random start result: 0.72
# i = 821 Random start result: 0.6000000000000001
# i = 822 Random start result: 0.8
# i = 823 Random start result: 0.76
# i = 824 Random start result: 0.76
# i = 825 Random start result: 0.8
# i = 826 Random start result: 0.72
# i = 827 Random start result: 0.76
# i = 828 Random start result: 0.64
# i = 829 Random start result: 0.8
# i = 830 Random start result: 0.72
# i = 831 Random start result: 0.8
# i = 832 Random start result: 0.44000000000000006
# i = 833 Random start result: 0.8
# i = 834 Random start result: 0.76
# i = 835 Random start result: 0.8
# i = 836 Random start result: 0.64
# i = 837 Random start result: 0.6799999999999999
# i = 838 Random start result: 0.72
# i = 839 Random start result: 0.72
# i = 840 Random start result: 0.8
# i = 841 Random start result: 0.6799999999999999
# i = 842 Random start result: 0.72
# i = 843 Random start result: 0.8
# i = 844 Random start result: 0.8
# i = 845 Random start result: 0.76
# i = 846 Random start result: 0.8
# i = 847 Random start result: 0.72
# i = 848 Random start result: 0.72
# i = 849 Random start result: 0.8
# i = 850 Random start result: 0.72
# i = 851 Random start result: 0.6799999999999999
# i = 852 Random start result: 0.76
# i = 853 Random start result: 0.8
# i = 854 Random start result: 0.8
# i = 855 Random start result: 0.64
# i = 856 Random start result: 0.76
# i = 857 Random start result: 0.8
# i = 858 Random start result: 0.6799999999999999
# i = 859 Random start result: 0.72
# i = 860 Random start result: 0.8
# i = 861 Random start result: 0.6799999999999999
# i = 862 Random start result: 0.8
# i = 863 Random start result: 0.76
# i = 864 Random start result: 0.8
# i = 865 Random start result: 0.8
# i = 866 Random start result: 0.8
# i = 867 Random start result: 0.8
# i = 868 Random start result: 0.56
# i = 869 Random start result: 0.8
# i = 870 Random start result: -1.32
# i = 871 Random start result: 0.56
# i = 872 Random start result: 0.76
# i = 873 Random start result: 0.76
# i = 874 Random start result: 0.52
# i = 875 Random start result: 0.76
# i = 876 Random start result: 0.72
# i = 877 Random start result: 0.76
# i = 878 Random start result: 0.8
# i = 879 Random start result: 0.6799999999999999
# i = 880 Random start result: 0.64
# i = 881 Random start result: 0.8
# i = 882 Random start result: 0.72
# i = 883 Random start result: 0.8
# i = 884 Random start result: 0.8
# i = 885 Random start result: 0.52
# i = 886 Random start result: 0.76
# i = 887 Random start result: 0.72
# i = 888 Random start result: 0.8
# i = 889 Random start result: 0.8
# i = 890 Random start result: 0.8
# i = 891 Random start result: 0.64
# i = 892 Random start result: 0.8
# i = 893 Random start result: 0.76
# i = 894 Random start result: 0.76
# i = 895 Random start result: 0.64
# i = 896 Random start result: 0.6799999999999999
# i = 897 Random start result: 0.76
# i = 898 Random start result: 0.76
# i = 899 Random start result: 0.6799999999999999
# i = 900 Random start result: 0.8
# i = 901 Random start result: 0.76
# i = 902 Random start result: 0.8
# i = 903 Random start result: 0.76
# i = 904 Random start result: 0.8
# i = 905 Random start result: 0.76
# i = 906 Random start result: 0.8
# i = 907 Random start result: 0.76
# i = 908 Random start result: 0.72
# i = 909 Random start result: 0.56
# i = 910 Random start result: 0.56
# i = 911 Random start result: 0.76
# i = 912 Random start result: 0.8
# i = 913 Random start result: 0.72
# i = 914 Random start result: 0.6799999999999999
# i = 915 Random start result: 0.56
# i = 916 Random start result: 0.64
# i = 917 Random start result: 0.56
# i = 918 Random start result: 0.6000000000000001
# i = 919 Random start result: 0.6799999999999999
# i = 920 Random start result: 0.8
# i = 921 Random start result: 0.8
# i = 922 Random start result: 0.8
# i = 923 Random start result: 0.76
# i = 924 Random start result: 0.8
# i = 925 Random start result: 0.8
# i = 926 Random start result: 0.56
# i = 927 Random start result: 0.8
# i = 928 Random start result: 0.72
# i = 929 Random start result: 0.72
# i = 930 Random start result: 0.6799999999999999
# i = 931 Random start result: 0.76
# i = 932 Random start result: 0.8
# i = 933 Random start result: 0.8
# i = 934 Random start result: 0.72
# i = 935 Random start result: 0.6799999999999999
# i = 936 Random start result: 0.72
# i = 937 Random start result: 0.4800000000000001
# i = 938 Random start result: 0.76
# i = 939 Random start result: 0.72
# i = 940 Random start result: 0.64
# i = 941 Random start result: 0.72
# i = 942 Random start result: 0.64
# i = 943 Random start result: 0.72
# i = 944 Random start result: 0.72
# i = 945 Random start result: 0.8
# i = 946 Random start result: 0.72
# i = 947 Random start result: 0.76
# i = 948 Random start result: 0.76
# i = 949 Random start result: 0.8
# i = 950 Random start result: 0.72
# i = 951 Random start result: 0.8
# i = 952 Random start result: 0.76
# i = 953 Random start result: 0.72
# i = 954 Random start result: 0.64
# i = 955 Random start result: 0.4800000000000001
# i = 956 Random start result: 0.8
# i = 957 Random start result: 0.64
# i = 958 Random start result: 0.8
# i = 959 Random start result: 0.8
# i = 960 Random start result: 0.6799999999999999
# i = 961 Random start result: 0.8
# i = 962 Random start result: 0.8
# i = 963 Random start result: 0.6799999999999999
# i = 964 Random start result: 0.6799999999999999
# i = 965 Random start result: 0.76
# i = 966 Random start result: 0.72
# i = 967 Random start result: 0.76
# i = 968 Random start result: 0.72
# i = 969 Random start result: 0.8
# i = 970 Random start result: 0.76
# i = 971 Random start result: 0.8
# i = 972 Random start result: 0.6799999999999999
# i = 973 Random start result: 0.6799999999999999
# i = 974 Random start result: 0.6799999999999999
# i = 975 Random start result: 0.8
# i = 976 Random start result: 0.76
# i = 977 Random start result: 0.64
# i = 978 Random start result: 0.72
# i = 979 Random start result: 0.8
# i = 980 Random start result: 0.72
# i = 981 Random start result: 0.6000000000000001
# i = 982 Random start result: 0.72
# i = 983 Random start result: 0.6799999999999999
# i = 984 Random start result: 0.72
# i = 985 Random start result: 0.6000000000000001
# i = 986 Random start result: 0.64
# i = 987 Random start result: 0.8
# i = 988 Random start result: 0.6799999999999999
# i = 989 Random start result: 0.8
# i = 990 Random start result: 0.6799999999999999
# i = 991 Random start result: 0.8
# i = 992 Random start result: 0.56
# i = 993 Random start result: 0.8
# i = 994 Random start result: 0.76
# i = 995 Random start result: 0.8
# i = 996 Random start result: 0.64
# i = 997 Random start result: 0.6799999999999999
# i = 998 Random start result: 0.76
# i = 999 Random start result: 0.4800000000000001
# max = 0.8
# min = -1.4
# mean = 0.7106800000000001
# std = 0.22374525156972605
# (0.8, -1.4, 0.7106800000000001)
